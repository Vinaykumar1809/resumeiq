# %% [markdown]
# # ResumeIQ Model Experimentation
#
# Use this notebook to inspect the dataset, run `src.model_training`, and compare syllabus-aligned algorithms: Naive Bayes, Decision Tree, k-NN, and SVM.

# %%
from pathlib import Path
import pandas as pd

dataset_path = Path('../data/raw/resume_dataset.csv')
pd.read_csv(dataset_path).head()

# %%
import sys
sys.path.append('..')
from src.model_training import train_and_compare_models

train_and_compare_models()
